# %%
#now, we will start the first unit properly
#first, lets start with imports and device agnostic code:

import torch
from torch import nn
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

if torch.cuda.is_available():
    device = "cuda"
elif torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cpu"


print(f"Torch Version: {torch.__version__}, device: {device}")
# Out:
# Torch Version: 2.5.1, device: mps

# %%
#now, lets create the dataset. 

start = 0
end = 100
step = 1
X = torch.arange(start=start,end=end,step=step)

guess_weight = 0.7
guess_bias = 0.3
y = guess_weight * X + guess_bias

#on the dataset, can preform tensor slicing: [start:end:step,] ... same as string indexing, only with comma to separate
#default start is index 0, stop is last index, step is the step for the index
#when step is negative, it switches start and stop

train_amount = 0.8
train_features = X[:int(train_amount * len(X)):]
test_features = X[int(train_amount * len(X))::]
train_labels = y[:int(train_amount * len(y)):]
test_labels = y[int(train_amount * len(y))::]

#now, lets create a dataframe:
train_data = {
    "Train Features":train_features,
    "Train Labels":train_labels,
    "Test Features":test_features,
    "Test Labels":test_labels
}
df = pd.DataFrame(data=data)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 29
#      22 #now, lets create a dataframe:
#      23 data = {
#      24     "Train Features":train_features,
#      25     "Train Labels":train_labels,
#      26     "Test Features":test_features,
#      27     "Test Labels":test_labels
#      28 }
# ---> 29 df = pd.DataFrame(data=data)
#      30 df.head()
#
# File ~/miniconda3/envs/ai_mac/lib/python3.12/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
# ...

# %%
#create a pl
